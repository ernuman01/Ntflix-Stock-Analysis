# %% [markdown]
# # Netflix Stock Analysis

# %% [markdown]
# # Objective

# %% [markdown]
# ### Volume Of Stock traded

# %% [markdown]
# ### Netflix Stock Price - High, Open, Low, Close

# %% [markdown]
# ### Netflix stock Price - Day, Month, Year Wise

# %% [markdown]
# ### Top 5 Dates With HIghest Stock Price

# %% [markdown]
# ### Top 5 Dates With Lowest Stock Price

# %% [markdown]
# # Netflix Stock Analysis Project

# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
from datetime import datetime

# %%
#uploading data

df = pd.read_csv("Netflix.csv")

# %%
df.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume
# 0  2002-05-23  1.156429  1.242857  1.145714  1.196429   1.196429  104790000
# 1  2002-05-24  1.214286  1.225000  1.197143  1.210000   1.210000   11104800
# 2  2002-05-28  1.213571  1.232143  1.157143  1.157143   1.157143    6609400
# 3  2002-05-29  1.164286  1.164286  1.085714  1.103571   1.103571    6757800
# 4  2002-05-30  1.107857  1.107857  1.071429  1.071429   1.071429   10154200

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %% [markdown]
# ## Obje. 1. Volume Of Stock Traded Yearly.

# %%
# changing index 0,1,2,3 to Date as index

sns.set(rc = {'figure.figsize':(10,5)})

# %%
df["Date"] = pd.to_datetime(df["Date"])
df = df.set_index("Date")
df.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2002-05-23  1.156429  1.242857  1.145714  1.196429   1.196429  104790000
# 2002-05-24  1.214286  1.225000  1.197143  1.210000   1.210000   11104800
# 2002-05-28  1.213571  1.232143  1.157143  1.157143   1.157143    6609400
# 2002-05-29  1.164286  1.164286  1.085714  1.103571   1.103571    6757800
# 2002-05-30  1.107857  1.107857  1.071429  1.071429   1.071429   10154200

# %% [markdown]
# Now the index set as Date

# %% [markdown]
# ### Visualisation

# %%
sns.lineplot(x = df.index, y = df['Volume'], label = 'Volume')

plt.title('Volume Vs Time')
# Out:
# Text(0.5, 1.0, 'Volume Vs Time')

# %% [markdown]
# The above are desired grapgh in which 2012 is highest traded volume.

# %% [markdown]
# ### Obje - Netflix Stock Price - High, Open, Low, Close

# %%
df.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2002-05-23  1.156429  1.242857  1.145714  1.196429   1.196429  104790000
# 2002-05-24  1.214286  1.225000  1.197143  1.210000   1.210000   11104800
# 2002-05-28  1.213571  1.232143  1.157143  1.157143   1.157143    6609400
# 2002-05-29  1.164286  1.164286  1.085714  1.103571   1.103571    6757800
# 2002-05-30  1.107857  1.107857  1.071429  1.071429   1.071429   10154200

# %%
df.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
df.plot(y = ['High', 'Close', 'Open'], title = 'Netfkix stock price' )
# Out:
# <Axes: title={'center': 'Netfkix stock price'}, xlabel='Date'>

# %% [markdown]
# The above are desire grapgh

# %% [markdown]
# ### Obje. 3. Netflix stock Price - Day, Month, Year Wise

# %%
# 3 graoghs base on date, time, year base using Group by.

fig, (ax1, ax2, ax3) = plt.subplots(3, figsize = (15,10))

df.groupby(df.index.day).mean().plot(y = 'Volume', ax = ax1, xlabel = 'Day')

df.groupby(df.index.month).mean().plot(y = 'Volume', ax = ax2, xlabel = 'Month')

df.groupby(df.index.year).mean().plot(y = 'Volume', ax = ax3, xlabel = 'Year')
# Out:
# <Axes: xlabel='Year'>

# %% [markdown]
# # Top 5 Dates With HIghest Stock Price

# %%
df.head(1)
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2002-05-23  1.156429  1.242857  1.145714  1.196429   1.196429  104790000

# %%
a = df.sort_values(by = 'High', ascending = False).head(5)

a['High']
# Out:
# Date
# 2021-09-30    619.000000
# 2021-09-08    615.599976
# 2021-09-07    613.849976
# 2021-09-29    609.880005
# 2021-09-10    609.450012
# Name: High, dtype: float64

# %% [markdown]
# ### Top 5 Dates With Lowest Stock Price.

# %%
b = df.sort_values(by = 'Low', ascending = True).head(5)

# %%
a['Low']
# Out:
# Date
# 2021-09-30    608.049988
# 2021-09-08    595.710022
# 2021-09-07    593.989990
# 2021-09-29    588.010010
# 2021-09-10    593.669983
# Name: Low, dtype: float64

# %% [markdown]
# ## Visualisation

# %%
fig, axes = plt.subplots(nrows = 1, ncols = 2, sharex = True, figsize = (12,5))

fig.suptitle('High & Low stock valuesper per period of time', fontsize = 18)

sns.lineplot(ax = axes[0], y = df['High'], x = df.index, color = 'green')

sns.lineplot(ax = axes[1], y = df['Low'], x = df.index, color = 'red')
# Out:
# <Axes: xlabel='Date', ylabel='Low'>

# %% [markdown]
# So Above are desired Outcome
